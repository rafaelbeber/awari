# %% [markdown]
# ### Desafio 12
#
# Escreva uma função em Python para verificar a validade de uma senha.
#
# Validação:
#
# * Pelo menos 1 letra entre [a-z] e 1 letra entre [A-Z].
# * Pelo menos 1 número entre [0-9].
# * Pelo menos 1 caractere de [$ # @].
# * Comprimento mínimo de 6 caracteres.
# * Comprimento máximo de 16 caracteres.
#
# Entradas: "12345678", "J3sus0", "#Te5t300", "J*90j12374", "Michheeul", "Monk3y6"
#
# A saída deve ser a senha e um texto indicando se a senha é válida ou inválida:
#
# ```
# "1234" - Senha inválida
# "Qw#1234" - Senha válida
# ```

# %%
# Seu código

import re
def test_password(password):
 
  min_num = 1
  min_maiscula = 1
  min_minusula = 1
  min_especial = 1
  min_tamanho = 6
  max_tamanho = 16
 
  if len(password) >= min_tamanho:
    if len(password) <= max_tamanho:
      if len(re.findall(r"[A-Z]", password)) >= min_maiscula:
        if len(re.findall(r"[a-z]", password)) >= min_minusula:
          if len(re.findall(r"[0-9]", password)) >= min_num:
            if len(re.findall(r"[@#$]", password)) >= min_especial:
              print('senha válida')
            else:
              print('senha inválida')
          else:
            print('senha inválida')
        else:
          print('senha inválida')
      else:
        print('senha inválida')
    else:
      print('senha inválida')
  else:
    print('senha inválida')
 
test_password("12345678")
test_password("J3sus0")
test_password("#Te5t300")
test_password("J*90j12374")
test_password("Michheeul")
test_password("Monk3y6")
# Out:
# senha inválida
# senha inválida
# senha válida
# senha inválida
# senha inválida
# senha inválida

# %%
senha = '#Te5t300'
sum(s.isupper() for s in senha)
# Out:
# 1

# %%
sum(s.islower() for s in senha)
# Out:
# 2

# %%
sum(s.isdigit() for s in senha)
# Out:
# 4

# %%
sum(s in char_especial for s in senha)
# Out:
# 1

# %%
soma = 1 if sum(s.isdigit() for s in senha) > 0 else False
# Out:
# 1

# %%
def valida_senha(senha):
  soma = 0
  soma += 1 if sum(s.isupper() for s in senha) > 0 else 0
  soma += 1 if sum(s.islower() for s in senha) > 0 else 0
  soma += 1 if sum(s.isdigit() for s in senha) > 0 else 0
  soma += 1 if sum(s in char_especial for s in senha) > 0 else 0
  soma += 1 if sum(s in char_especial for s in senha) > 0 else 0

  if soma >= 5:
    return 'Senha Válida'
  else:
    return 'Senha inválida'

# %%
entrada = ["12345678", "J3sus0", "#Te5t300", "J*90j12374", "Michheeul", "Monk3y6"]
char_especial = ['@','$', '#']

for senha in entrada:
  print(valida_senha(senha));
# Out:
# Senha inválida
# Senha inválida
# Senha Válida
# Senha inválida
# Senha inválida
# Senha inválida
