# %% [markdown]
# ### Desafio 8
#
# Escreva um script Python para encontrar as 10 palavras mais longas em um arquivo.
#
# O arquivo TXT está localizado na mesma pasta do projeto (texto.txt).

# %%
# Seu código
import collections
import re


# !wget('https://raw.githubusercontent.com/rafaelbeber/br-python-challenges/master/texto.txt')
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `'https://raw.githubusercontent.com/rafaelbeber/br-python-challenges/master/texto.txt''
# /bin/bash: -c: line 0: `wget('https://raw.githubusercontent.com/rafaelbeber/br-python-challenges/master/texto.txt')'

# %%
#abre arquvio texto
arquivo_txt = open('texto.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-69425ba577f8> in <module>()
#       1 #abre arquvio texto
# ----> 2 arquivo_txt = open('texto.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'texto.txt'

# %%
#remove caracteres especias, exceto o espaço
texto = re.sub('[^0-9a-zA-Z ]+', '', arquivo_txt.read())

#quebra o texto em palavras
palavras = texto.split()

#remove palavras duplicadas
palavras_unicas = collections.Counter(palavras)

#orgazina a lista pelo tamanho das palavras de forma crescente
lista_organizada = sorted(palavras_unicas, key=len, reverse=True)

#pega as 10 ultimas palavras da lista
lista_organizada[:10]
